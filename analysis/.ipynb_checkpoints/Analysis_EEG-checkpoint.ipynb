# %% [markdown]
# # EEG Analysis Functions
# In this notebook, I will be creating EEG analysis and visualization functions. The goals are as follows:
# * Confirm signals via matplotlib visualizations
# * Process into conventional alpha, beta, theta, and gamma waves.
# * Create processing scripts for extracting meditation state, flow state, and concentration from the data.

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# Constants
csv_path = '../minMuse/data/'
csv_name = 'muse-recording_20191118T185915.csv'

# %%
pd_in = pd.read_csv(csv_path+csv_name)
pd_in.head()
# Out:
#       timestamp        eeg1        eeg2      eeg3      eeg4  eeg5(aux)
# 0  1.574122e+09    0.000000    0.000000 -0.488281  0.000000        0.0
# 1  1.574122e+09   -0.976562    0.000000  0.000000  0.488281        0.0
# 2  1.574122e+09   -9.277344  -32.226562 -0.488281 -3.417969        0.0
# 3  1.574122e+09   25.390625   68.847656  0.488281  3.906250        0.0
# 4  1.574122e+09 -132.812500 -390.136719  0.000000 -9.765625        0.0

# %%
plt.plot(pd_in['eeg1'][0:256])

# %%
fft_1 = np.fft.fft(pd_in['eeg1'])
fft_1
# Out:
# array([-531745.60546875+4.59294824e-11j, -300231.01783252+1.02149417e+05j,
#        -105658.7788147 +2.23487413e+05j, ...,
#        -151716.17891216-2.45845510e+05j, -105658.7788147 -2.23487413e+05j,
#        -300231.01783252-1.02149417e+05j])

# %%
plt.plot(fft_1)
print('Length of fft: ')
# Out:
# /home/aman/.local/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
